# %% [markdown]
# # 파이썬에서 데이터를 쉽게 다룰수 있는 라이브러리
# - 2차원 형태의 데이터를 집계하거나 전처리 등을 아주 쉽게 할 수있음
# -정형 데이터를 다루기 위한 라이브러리

# %% [markdown]
# - Datafram
#     - 2차원 구조로 되어있는 행렬 데이터
# - Series(여러개면 Dataframe이 된다.)
#     - 1 차원 구조로 되어있는 한 종류의 데이터

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# - Datafram 만들기 행렬구조의 리스트 데이터 프레임으로 반환

# %%
data = [
    ["A군",30,170],
    ["B군",25,180]
]
df = pd.DataFrame(data,columns=["이름" ,"나 이","키"])
df
# Out:
#    이름  나 이    키
# 0  A군   30  170
# 1  B군   25  180

# %%
df["이름"]
# Out:
# 0    A군
# 1    B군
# Name: 이름, dtype: object

# %%
df.이름
# Out:
# 0    A군
# 1    B군
# Name: 이름, dtype: object

# %%
df["나 이"] # 단어에공백이 있으면 이런식으로 해야됨
# Out:
# 0    30
# 1    25
# Name: 나 이, dtype: int64

# %%
arr = np.load("samsung_stock_2021.npy")
columns = ["시작가","상한가","하한가","종가"]
pd.DataFrame(arr,columns=columns)
# Out:
#        시작가    상한가    하한가     종가
# 0    81000  84400  80200  83000
# 1    81600  83900  81600  83900
# 2    83300  84500  82100  82200
# 3    82800  84200  82700  82900
# 4    83300  90000  83000  88800
# ..     ...    ...    ...    ...
# 243  80200  80800  80200  80500
# 244  80600  80600  79800  80200
# 245  80200  80400  79700  80300
# 246  80200  80200  78500  78800
# 247  78900  79500  78100  78300
#
# [248 rows x 4 columns]

# %%
data = {
    "이름" : ["A군","B군","C군"],
    "나이" : [35,33,28],
    "키" : [180.1,175.5,170.0]
}
pd.DataFrame(data)
# Out:
#    이름  나이      키
# 0  A군  35  180.1
# 1  B군  33  175.5
# 2  C군  28  170.0

# %%
DATA_PATH = (f'/content/drive/MyDrive/01-python/data/db.yaml/')

# %%
# !pip install pymysql
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 43 kB 1.5 MB/s
# ...

# %%
import yaml
DB_INFO =f"/content/drive/MyDrive/01-python/data/db.yaml"
with open(DB_INFO,'r') as f:
    db_info = yaml.load(f,Loader=yaml.Loder)
db_info

# %%
import yaml
DB_INFO ="/content/drive/MyDrive/01-python/data/db.yaml"
with open(DB_INFO,"r") as f:
    db_info = yaml.load(f,Loader=yaml.Loader)

# %%
import pymysql

conn = pymysql.connect(
    user = db_info["USER"],
    passwd =db_info["PASSWD"],
    host =db_info["HOST"],
    port =3306,
    db ="playdata"
)
conn

# %% [markdown]
# ## sql 이용 데이터프레임

# %%
df = pd.read_sql("select * from titanic_raw",conn)
df
# Out:
#       passengerid  survived  pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ...           ...       ...     ...
# 1304         1305         0       3
# 1305         1306         1       1
# 1306         1307         0       3
# 1307         1308         0       3
# 1308         1309         0       3
#
#                                                    name  gender   age  sibsp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# - to_csv 메소드
#  데이터 프레임을 csv 파일로 저장

# %%
df.to_csv(f"{DATA_PATH}titanic.csv",index = False)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-125-76c6409d2b42> in <module>
# ----> 1 df.to_csv(f"{DATA_PATH}titanic.csv",index = False)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ...

# %% [markdown]
# ## 저장법

# %%
df.to_csv(f"/content/drive/MyDrive/01-python/data/db.yaml""titanic.csv",index = False)

# %%
df = pd.read_csv(f"/content/drive/MyDrive/01-python/data/db.yaml""titanic.csv")
df
# Out:
#       passengerid  survived  pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ...           ...       ...     ...
# 1304         1305         0       3
# 1305         1306         1       1
# 1306         1307         0       3
# 1307         1308         0       3
# 1308         1309         0       3
#
#                                                    name  gender   age  sibsp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# D

# %% [markdown]
# - 데이터 프레임 정보 확인하기

# %%
df.columns
# Out:
# Index(['passengerid', 'survived', 'pclass', 'name', 'gender', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
df.info(verbose=True,null_counts=True) # 모든정보를 보고싶을때verbose=True null_counts=True 널값볼때
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   passengerid  1309 non-null   int64
#  1   survived     1309 non-null   int64
#  2   pclass       1309 non-null   int64
#  3   name         1309 non-null   object
#  4   gender       1309 non-null   object
#  5   age          1046 non-null   float64
#  6   sibsp        1309 non-null   int64
#  7   parch        1309 non-null   int64
#  8   ticket       1309 non-null   object
#  9   fare         1308 non-null   float64
#  10  cabin        295 non-null    object
#  11  embarked     1307 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 122.8+ KB
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# - 수치형 컬럼에 대한 요약 통계 보기

# %%
df.describe()
# Out:
#        passengerid     survived       pclass          age        sibsp  \
# count  1309.000000  1309.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000     0.377387     2.294882    29.881138     0.498854
# std     378.020061     0.484918     0.837836    14.413493     1.041658
# min       1.000000     0.000000     1.000000     0.170000     0.000000
# 25%     328.000000     0.000000     2.000000    21.000000     0.000000
# 50%     655.000000     0.000000     3.000000    28.000000     0.000000
# 75%     982.000000     1.000000     3.000000    39.000000     1.000000
# max    1309.000000     1.000000     3.000000    80.000000     8.000000
#
#              parch         fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %%
df.shape
# Out:
# (1309, 12)

# %%
df.head(40)
# Out:
#     passengerid  survived  pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
df.tail()
# Out:
#       passengerid  survived  pclass                          name  gender  \
# 1304         1305         0       3            Spector, Mr. Woolf    male
# 1305         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 1306         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 1307         1308         0       3           Ware, Mr. Frederick    male
# 1308         1309         0       3      Peter, Master. Michael J    male
#
#        age  sibsp  parch              ticket      fare cabin embarked
# 1304   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1305  39.0      0      0            PC 17758  108.9000  C105        C
# 1306  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307   NaN      0      0              359309    8.0500   NaN        S
# 1308   NaN      1      1                2668   22.3583   NaN        C

# %% [markdown]
# # 데이터 프레임 다루기

# %% [markdown]
# - copy 메소드
#     - 데이터프레임을 복사한다.
#     - 기본적으로 깊은복사

# %%
df_cp = df.copy()
df_cp.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name  gender   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# - 컬럼명 변경하기
# - 한번에 변경하기

# %%
cols = df_cp.columns.tolist()
cols[0] = "pid"
cols
# Out:
# ['pid',
#  'survived',
#  'pclass',
#  'name',
#  'gender',
#  'age',
#  'sibsp',
#  'parch',
#  'ticket',
#  'fare',
#  'cabin',
#  'embarked']

# %%
df_cp.columns = cols
df_cp.head()
# Out:
#    pid  survived  pclass                                               name  \
# 0    1         0       3                            Braund, Mr. Owen Harris
# 1    2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    3         1       3                             Heikkinen, Miss. Laina
# 3    4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4    5         0       3                           Allen, Mr. William Henry
#
#    gender   age  sibsp  parch            ticket     fare cabin embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
df_cp.columns[0]
# Out:
# 'pid'

# %% [markdown]
# df_cp.columns

# %%
df_cp.columns[0]= "dd"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-16b3000da37d> in <module>
# ----> 1 df_cp.columns[0]= "dd"
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    4583     @final
#    4584     def __setitem__(self, key, value):
# -> 4585         raise TypeError("Index does not support mutable operations")
#    4586
#    4587     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
cols = df_cp.columns.tolist()
cols[0]="psss"

# %%
cols_rename ={
    "survived" : "target"
}
df = df.rename(columns = cols_rename) # 새로운 컬럼을 생성하며 변경
df.head()
# Out:
#    이름  나 이    키
# 0  A군   30  170
# 1  B군   25  180

# %%
df_cp.rename(columns={"survived":"target"},inplace=True) # 컬럼 자체를 변경, 권장하지 않음
df.head()
# Out:
#    passengerid  target  pclass  \
# 0            1       0       3
# 1            2       1       1
# 2            3       1       3
# 3            4       1       1
# 4            5       0       3
#
#                                                 name  gender   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# - add_ptefix
#     - 컬럼명 앞부분에 공통된 문자열 붙혀주기

# %%
df.add_prefix("엿_")
# Out:
#       엿_passengerid  엿_target  엿_pclass  \
# 0                 1         0         3
# 1                 2         1         1
# 2                 3         1         3
# 3                 4         1         1
# 4                 5         0         3
# ...             ...       ...       ...
# 1304           1305         0         3
# 1305           1306         1         1
# 1306           1307         0         3
# 1307           1308         0         3
# 1308           1309         0         3
#
#                                                  엿_name 엿_gender  엿_age  \
# 0                               Braund, Mr. Owen Harris     male   22.0
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...   female   38.0
# 2                                Heikkinen, Miss. Laina   female   26.0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)   female   35.0
# 4                              Allen, Mr. William Henry     male   35.0
# ...

# %% [markdown]
# - add_suffix
#     - 컬럼명 뒷부분에 공통된 명 붙힘

# %%
df.add_suffix("_엥")
# Out:
#       passengerid_엥  target_엥  pclass_엥  \
# 0                 1         0         3
# 1                 2         1         1
# 2                 3         1         3
# 3                 4         1         1
# 4                 5         0         3
# ...             ...       ...       ...
# 1304           1305         0         3
# 1305           1306         1         1
# 1306           1307         0         3
# 1307           1308         0         3
# 1308           1309         0         3
#
#                                                  name_엥 gender_엥  age_엥  \
# 0                               Braund, Mr. Owen Harris     male   22.0
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...   female   38.0
# 2                                Heikkinen, Miss. Laina   female   26.0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)   female   35.0
# 4                              Allen, Mr. William Henry     male   35.0
# ...

# %% [markdown]
# - 특벙 컬럼들만 선택하기

# %%
cols = ["name","gender","age"]
df[cols].head()
# Out:
#                                                 name  gender   age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
target = df["target"]
target
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 1304    0
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Name: target, Length: 1309, dtype: int64

# %% [markdown]
# ## 컬럼 삭제하기
# - drop 메소드

# %%
# axis 이ㅣ용방범
df.drop("name",axis =1) # 리스트 형식으로 삭제 가능
# Out:
#       passengerid  target  pclass  gender   age  sibsp  parch  \
# 0               1       0       3    male  22.0      1      0
# 1               2       1       1  female  38.0      1      0
# 2               3       1       3  female  26.0      0      0
# 3               4       1       1  female  35.0      1      0
# 4               5       0       3    male  35.0      0      0
# ...           ...     ...     ...     ...   ...    ...    ...
# 1304         1305       0       3    male   NaN      0      0
# 1305         1306       1       1  female  39.0      0      0
# 1306         1307       0       3    male  38.5      0      0
# 1307         1308       0       3    male   NaN      0      0
# 1308         1309       0       3    male   NaN      1      1
#
#                   ticket      fare cabin embarked
# 0              A/5 21171    7.2500   NaN        S
# 1               PC 17599   71.2833   C85        C
# 2       STON/O2. 3101282    7.9250   NaN        S
# ...

# %%
df.drop(columns=["name","age"]) # 쌤은 이방법이 좀더 직관적이라고함
# Out:
#       passengerid  target  pclass  gender  sibsp  parch              ticket  \
# 0               1       0       3    male      1      0           A/5 21171
# 1               2       1       1  female      1      0            PC 17599
# 2               3       1       3  female      0      0    STON/O2. 3101282
# 3               4       1       1  female      1      0              113803
# 4               5       0       3    male      0      0              373450
# ...           ...     ...     ...     ...    ...    ...                 ...
# 1304         1305       0       3    male      0      0           A.5. 3236
# 1305         1306       1       1  female      0      0            PC 17758
# 1306         1307       0       3    male      0      0  SOTON/O.Q. 3101262
# 1307         1308       0       3    male      0      0              359309
# 1308         1309       0       3    male      1      1                2668
#
#           fare cabin embarked
# ...

# %%
df.drop(3,axis=0) # 행을 삭제 하는 일은 잘 없음
# Out:
#       passengerid  target  pclass  \
# 0               1       0       3
# 1               2       1       1
# 2               3       1       3
# 4               5       0       3
# 5               6       0       3
# ...           ...     ...     ...
# 1304         1305       0       3
# 1305         1306       1       1
# 1306         1307       0       3
# 1307         1308       0       3
# 1308         1309       0       3
#
#                                                    name  gender   age  sibsp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 4                              Allen, Mr. William Henry    male  35.0      0
# 5                                      Moran, Mr. James    male   NaN      0
# ...                                                 ...     ...   ...    ...
# ...

# %%
df.drop("pclass",axis=1)
df
# Out:
#       passengerid  target  pclass  \
# 0               1       0       3
# 1               2       1       1
# 2               3       1       3
# 3               4       1       1
# 4               5       0       3
# ...           ...     ...     ...
# 1304         1305       0       3
# 1305         1306       1       1
# 1306         1307       0       3
# 1307         1308       0       3
# 1308         1309       0       3
#
#                                                    name  gender   age  sibsp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# ...

# %%
df["target"] = target
df.head()
# Out:
#    passengerid  target  pclass  \
# 0            1       0       3
# 1            2       1       1
# 2            3       1       3
# 3            4       1       1
# 4            5       0       3
#
#                                                 name  gender   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sort_values(by = "age", ascending=False) #내림차순
# Out:
#       passengerid  target  pclass  \
# 630           631       1       1
# 987           988       1       1
# 851           852       0       3
# 493           494       0       1
# 96             97       0       1
# ...           ...     ...     ...
# 1299         1300       1       3
# 1301         1302       1       3
# 1304         1305       0       3
# 1307         1308       0       3
# 1308         1309       0       3
#
#                                                    name  gender   age  sibsp  \
# 630                Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# 987   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 851                                 Svensson, Mr. Johan    male  74.0      0
# 493                             Artagaveytia, Mr. Ramon    male  71.0      0
# 96                            Goldschmidt, Mr. George B    male  71.0      0
# ...                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## 데이터 프레임 섞기
#     - frac: 섞은후에 반환할 비율을 0~1 사이에 값을 넣으면 된다.

# %%
from pandas.core.common import random_state
df2 = df.sample(frac=1,random_state=42) #random_state 시드값 키워드 frac=0.2 비율을 정할수있음 1이 백프로
df2
# Out:
#       passengerid  target  pclass  \
# 1148         1149       0       3
# 1049         1050       0       1
# 982           983       0       3
# 808           809       0       2
# 1195         1196       1       3
# ...           ...     ...     ...
# 1095         1096       0       2
# 1130         1131       1       1
# 1294         1295       0       1
# 860           861       0       3
# 1126         1127       0       3
#
#                                              name  gender   age  sibsp  parch  \
# 1148                        Niklasson, Mr. Samuel    male  28.0      0      0
# 1049                     Borebank, Mr. John James    male  42.0      0      0
# 982                            Pedersen, Mr. Olaf    male   NaN      0      0
# 808                             Meyer, Mr. August    male  39.0      0      0
# 1195            McCarthy, Miss. Catherine Katie""  female   NaN      0      0
# ...                                           ...     ...   ...    ...    ...
# ...

# %% [markdown]
# ## 행렬다루기
# - 데이터프레임에서는 행에대한 이름을 index 열에대한ㅇ이름을columns 라 한다
# - 데이터프레임드 넘파이를 기반으로 돌아가기에 행렬 개념이다.

# %% [markdown]
# ## iloc
#     - 행번호와 열번호를 이용한 행렬 슬라이싱

# %%
df.head()
# Out:
#    passengerid  target  pclass  \
# 0            1       0       3
# 1            2       1       1
# 2            3       1       3
# 3            4       1       1
# 4            5       0       3
#
#                                                 name  gender   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2.iloc[:5,1:5]
# Out:
#       target  pclass                               name  gender
# 1148       0       3              Niklasson, Mr. Samuel    male
# 1049       0       1           Borebank, Mr. John James    male
# 982        0       3                 Pedersen, Mr. Olaf    male
# 808        0       2                  Meyer, Mr. August    male
# 1195       1       3  McCarthy, Miss. Catherine Katie""  female

# %%
num_rows = [1,3,5]
num_cols = [0,4,2]
df2.iloc[num_rows,num_cols]
# Out:
#       passengerid  gender  pclass
# 1049         1050    male       1
# 808           809    male       2
# 240           241  female       3

# %%
df2.iloc[:10,:-3]
# Out:
#       passengerid  target  pclass  \
# 1148         1149       0       3
# 1049         1050       0       1
# 982           983       0       3
# 808           809       0       2
# 1195         1196       1       3
# 240           241       0       3
# 1118         1119       1       3
# 596           597       1       2
# 924           925       1       3
# 65             66       1       3
#
#                                                    name  gender   age  sibsp  \
# 1148                              Niklasson, Mr. Samuel    male  28.0      0
# 1049                           Borebank, Mr. John James    male  42.0      0
# 982                                  Pedersen, Mr. Olaf    male   NaN      0
# 808                                   Meyer, Mr. August    male  39.0      0
# 1195                  McCarthy, Miss. Catherine Katie""  female   NaN      0
# 240                               Zabour, Miss. Thamine  female   NaN      1
# ...

# %% [markdown]
# ## loc
#     - index 명과 columns 명을 이용한 슬라이싱
#     - 마스킹 을 이욯해서 행과 열 선택이 가능하다.

# %%
df.loc[3] # 일반슬라이싱과 다르게 앤드 번호로 나옴
# Out:
#       passengerid  target  pclass                      name gender   age  \
# 1148         1149       0       3     Niklasson, Mr. Samuel   male  28.0
# 1049         1050       0       1  Borebank, Mr. John James   male  42.0
# 982           983       0       3        Pedersen, Mr. Olaf   male   NaN
#
#       sibsp  parch  ticket    fare cabin embarked
# 1148      0      0  363611   8.050   NaN        S
# 1049      0      0  110489  26.550   D22        S
# 982       0      0  345498   7.775   NaN        S

# %%
df.loc[:,["embarked","age","fare"]]
# Out:
#      embarked   age      fare
# 0           S  22.0    7.2500
# 1           C  38.0   71.2833
# 2           S  26.0    7.9250
# 3           S  35.0   53.1000
# 4           S  35.0    8.0500
# ...       ...   ...       ...
# 1304        S   NaN    8.0500
# 1305        C  39.0  108.9000
# 1306        S  38.5    7.2500
# 1307        S   NaN    8.0500
# 1308        C   NaN   22.3583
#
# [1309 rows x 3 columns]

# %%
df.iloc[50:51,]
# Out:
#     passengerid  target  pclass                        name gender  age  \
# 50           51       0       3  Panula, Master. Juha Niilo   male  7.0
#
#     sibsp  parch   ticket     fare cabin embarked
# 50      4      1  3101295  39.6875   NaN        S

# %%
idx = [1,2,3]
cols=["name","age","embarked"]
df.loc[idx,cols]
# Out:
#                                                 name   age embarked
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0        C
# 2                             Heikkinen, Miss. Laina  26.0        S
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0        S

# %%
df2.head()
# Out:
#       passengerid  target  pclass                               name  gender  \
# 1148         1149       0       3              Niklasson, Mr. Samuel    male
# 1049         1050       0       1           Borebank, Mr. John James    male
# 982           983       0       3                 Pedersen, Mr. Olaf    male
# 808           809       0       2                  Meyer, Mr. August    male
# 1195         1196       1       3  McCarthy, Miss. Catherine Katie""  female
#
#        age  sibsp  parch  ticket    fare cabin embarked
# 1148  28.0      0      0  363611   8.050   NaN        S
# 1049  42.0      0      0  110489  26.550   D22        S
# 982    NaN      0      0  345498   7.775   NaN        S
# 808   39.0      0      0  248723  13.000   NaN        S
# 1195   NaN      0      0  383123   7.750   NaN        Q

# %%
df2 = df2.reset_index(drop=True) # 기존 인덱스를 삭제하면서 새로운 인덱스 생성 가능
df2
# Out:
#       passengerid  target  pclass  \
# 0            1149       0       3
# 1            1050       0       1
# 2             983       0       3
# 3             809       0       2
# 4            1196       1       3
# ...           ...     ...     ...
# 1304         1096       0       2
# 1305         1131       1       1
# 1306         1295       0       1
# 1307          861       0       3
# 1308         1127       0       3
#
#                                              name  gender   age  sibsp  parch  \
# 0                           Niklasson, Mr. Samuel    male  28.0      0      0
# 1                        Borebank, Mr. John James    male  42.0      0      0
# 2                              Pedersen, Mr. Olaf    male   NaN      0      0
# 3                               Meyer, Mr. August    male  39.0      0      0
# 4               McCarthy, Miss. Catherine Katie""  female   NaN      0      0
# ...                                           ...     ...   ...    ...    ...
# ...

# %% [markdown]
# - ## 마스킹을 이용한 방법
#     - loc 를 사용해야한다,

# %%
mark = df2["target"] == 1 # 생존자만 찾기
mark
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1304    False
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: target, Length: 1309, dtype: bool

# %%
df2.loc[mark]
# Out:
#       passengerid  target  pclass  \
# 4            1196       1       3
# 6            1119       1       3
# 7             597       1       2
# 8             925       1       3
# 9              66       1       3
# ...           ...     ...     ...
# 1296          872       1       1
# 1299          331       1       3
# 1300         1239       1       3
# 1303         1045       1       3
# 1305         1131       1       1
#
#                                                    name  gender   age  sibsp  \
# 4                     McCarthy, Miss. Catherine Katie""  female   NaN      0
# 6                                McNeill, Miss. Bridget  female   NaN      0
# 7                            Leitch, Miss. Jessie Wills  female   NaN      0
# 8     Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"  female   NaN      1
# 9                              Moubarek, Master. Gerios    male   NaN      1
# ...                                                 ...     ...   ...    ...
# ...

# %%
True ==1 , True ==2
# Out:
# (True, False)

# %%
mask1 = df2["target"]  ==1
mask2 = df2["age"]  <20
df2.loc[mask1 &mask2].head()
# Out:
#     passengerid  target  pclass  \
# 23          262       1       3
# 29          193       1       3
# 31          428       1       2
# 36          209       1       3
# 39          185       1       3
#
#                                                  name  gender   age  sibsp  \
# 23                  Asplund, Master. Edvin Rojj Felix    male   3.0      4
# 29    Andersen-Jensen, Miss. Carla Christine Nielsine  female  19.0      1
# 31  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
# 36                          Carr, Miss. Helen "Ellen"  female  16.0      0
# 39                Kink-Heilmann, Miss. Luise Gretchen  female   4.0      0
#
#     parch  ticket     fare cabin embarked
# 23      2  347077  31.3875   NaN        S
# 29      0  350046   7.8542   NaN        S
# 31      0  250655  26.0000   NaN        S
# 36      0  367231   7.7500   NaN        Q
# 39      2  315153  22.0250   NaN        S

# %%
data = [
    ["A군",30,170],
    ["B군",25,180],
    ["C군",30,175]
]
df_info = pd.DataFrame(data,columns=["이름" ,"나 이","키"])
df_info
# Out:
#    이름  나 이    키
# 0  A군   30  170
# 1  B군   25  180
# 2  C군   30  175

# %% [markdown]
# ## 컬럼추가하기

# %%
cols =["주소","전화번호"]
rows =[
    ["강남","010-1111-1111"],
    ["강북","010-2222-2222"],
    ["강동","010-3333-3333"]
]
df_info[cols] = rows
df_info
# Out:
#    이름  나 이    키  주소           전화번호
# 0  A군   30  170  강남  010-1111-1111
# 1  B군   25  180  강북  010-2222-2222
# 2  C군   30  175  강동  010-3333-3333

# %% [markdown]
# ## 난값

# %%
df_info["전화번호"] = np.nan
df_info
# Out:
#    이름  나 이    키  주소  전화번호
# 0  A군   30  170  강남   NaN
# 1  B군   25  180  강북   NaN
# 2  C군   30  175  강동   NaN

# %%
df_info.loc[1,"전화번호"] = "010-2222-2222"
df_info
# Out:
#    이름  나 이    키  주소           전화번호
# 0  A군   30  170  강남            0.0
# 1  B군   25  180  강북  010-2222-2222
# 2  C군   30  175  강동            0.0

# %%
replace_dict = {"male":1,"female":0}
df["gender"].map(replace_dict)
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 1304    1
# 1305    0
# 1306    1
# 1307    1
# 1308    1
# Name: gender, Length: 1309, dtype: int64
